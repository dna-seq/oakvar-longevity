# %% [markdown]
# ## LongevityMap genes splitting
#
# Source of original data: [https://genomics.senescence.info](https://genomics.senescence.info/longevity/)<br />
# *(LongevityMap build 3, release date: 2017 June 24, number of genes: 884)*

# %%
import pandas as pd
import re
from pathlib import Path

# %%
debug_local = True#False
local = Path("..").resolve()
data  = local / "data"
input = data / "input"
output = data / "output"

# %%
# read original data into dataFrame
inputname=Path(input / "longevity_genes.csv").resolve()

df = pd.read_csv(inputname)

print("Dimension:", df.shape)
df.head()
# Out:
# Dimension: (550, 7)
#   id      Association Population       Variant(s)   Gene(s)   PubMed  \
# 0  1  non-significant      Dutch          HLA-B40     HLA-B  1859103
# 1  2  non-significant      Dutch         HLA-DRB5  HLA-DRB5  1859103
# 2  3  non-significant    Finnish             APOB      APOB  8018664
# 3  4      significant    Finnish            APOC3     APOC3  8018664
# 4  5      significant    Finnish  rs7412,rs429358      APOE  8018664
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# <br />
#
# ### Clean some data

# %%
# if string in the column 'Variant(s)' contains comma at the end, delete this last character (ignore records that contains NaN)
print("In the explored column, number of records with comma at the end:",
      len(df[df['Variant(s)'].str.endswith(',', na=False)]), end='')

df['Variant(s)'] = df['Variant(s)'].map(lambda st: st[:-1] if st.endswith(',') else st, na_action='ignore')

# check that we eliminate all cases with comma at the end
assert len(df[df['Variant(s)'].str.endswith(',', na=False)]) == 0, "Something wrong with removing comma at the end of string"
print('  - cleaned')
# Out:
# In the explored column, number of records with comma at the end: 1  - cleaned

# %%
# if string in the column 'Variant(s)' contains two commas in a row, replace them by one comma
print("In the explored column, number of records containing two commas in a row:",
      len(df[df['Variant(s)'].str.contains(',,', na=False)]), end='')

df['Variant(s)'] = df['Variant(s)'].str.replace(',,', ',')

# check that we eliminate all cases with two commas in a row
assert len(df[df['Variant(s)'].str.contains(',,', na=False)]) == 0, "Something wrong with removing two commas in a row"
print('  - cleaned')
# Out:
# In the explored column, number of records containing two commas in a row: 0  - cleaned

# %%
# Last columns of the dataFrame contains only NaN value.
# Make sure of this and delete this column as unnecessary.
assert df['Unnamed: 6'].isna().all(), "In the column 'Unnamed: 6' there is at least 1 record with value other than Nan"
del df['Unnamed: 6']

print("Dimension:", df.shape)
df.head()
# Out:
# Dimension: (550, 6)
#   id      Association Population       Variant(s)   Gene(s)   PubMed
# 0  1  non-significant      Dutch          HLA-B40     HLA-B  1859103
# 1  2  non-significant      Dutch         HLA-DRB5  HLA-DRB5  1859103
# 2  3  non-significant    Finnish             APOB      APOB  8018664
# 3  4      significant    Finnish            APOC3     APOC3  8018664
# 4  5      significant    Finnish  rs7412,rs429358      APOE  8018664

# %%
# read auxilary data into dataFrame
inputname2=Path(output / "longevity_map_descriptions.csv").resolve()
df2 = pd.read_csv(inputname2)
df2.head()
# Out:
#   id                                       Study Design  \
# 0  1  964 inhabitants aged 85 years and over and 244...
# 1  2  The apolipoprotein B Xba I polymorphism was ex...
# 2  3  964 inhabitants aged 85 years and over and 244...
# 3  4  The Sst I polymorphism was examined in 179 Fin...
# 4  5  The common polymorphism of apolipoprotein E (E...
#
#                                          Conclusions
# 0  Without correcting for multiple testing, HLA-D...
# 1  The frequencies of the Xba I alleles among the...
# 2  Without correcting for multiple testing, HLA-B...
# 3  The S2 allele (Sst I restriction site present)...
# 4  The frequency of the E2 allele was higher and ...

# %%
df=pd.merge(df, df2, on="id", how="left")
df.head()
# Out:
#   id      Association Population       Variant(s)   Gene(s)   PubMed  \
# 0  1  non-significant      Dutch          HLA-B40     HLA-B  1859103
# 1  2  non-significant      Dutch         HLA-DRB5  HLA-DRB5  1859103
# 2  3  non-significant    Finnish             APOB      APOB  8018664
# 3  4      significant    Finnish            APOC3     APOC3  8018664
# 4  5      significant    Finnish  rs7412,rs429358      APOE  8018664
#
#                                         Study Design  \
# 0  964 inhabitants aged 85 years and over and 244...
# 1  The apolipoprotein B Xba I polymorphism was ex...
# 2  964 inhabitants aged 85 years and over and 244...
# 3  The Sst I polymorphism was examined in 179 Fin...
# 4  The common polymorphism of apolipoprotein E (E...
#
#                                          Conclusions
# 0  Without correcting for multiple testing, HLA-D...
# 1  The frequencies of the Xba I alleles among the...
# 2  Without correcting for multiple testing, HLA-B...
# 3  The S2 allele (Sst I restriction site present)...
# 4  The frequency of the E2 allele was higher and ...

# %% [markdown]
# <br />
#
# ### Preliminary separation of original dataFrame into several dataFrames

# %%
# Seperate records that do not have values in the column 'Variant(s)'
df_var_nan = df[(df['Variant(s)'].isna())]

print("Dimension:", df_var_nan.shape)
df_var_nan.head()
# Out:
# Dimension: (16, 8)
#       id      Association            Population Variant(s) Gene(s)    PubMed  \
# 255  258      significant  American (Caucasian)        NaN    TP53  20824210
# 256  261  non-significant  American (Caucasian)        NaN    TP53  20824210
# 275  280      significant              European        NaN    TP53  23286790
# 276  281      significant              European        NaN    TP53  23286790
# 277  282      significant              European        NaN    TP53  23286790
#
#                                           Study Design  \
# 255  Alleles in candidate pathways (GH/IGF1 signali...
# 256  Alleles in candidate pathways (GH/IGF1 signali...
# 275  Genome-wide linkage scan in 2118 European nona...
# 276  The -11377C > G, -11391G > A, and -11426A > G ...
# 277  Genome-wide association study in 801 centenari...
#
#                                            Conclusions
# 255  Eleven SNPs (in GSR, KL, GHRHR, INS, GHSR, IGF...
# 256  Eleven SNPs (in GSR, KL, GHRHR, INS, GHSR, IGF...
# 275  Four regions showed linkage to longevity (14q1...
# 276  A very rare AA genotype of the -11391G > A pol...
# 277  rs2075650, in a TOMM40 intron but a proxy of S...

# %%
# rows that have some info in the column 'Variant(s)' - this is intermediate dataFrame for further splitting
df_var_not_nan = df[(df['Variant(s)'].notna())]

print("Dimension:", df_var_not_nan.shape)
df_var_not_nan.head()
# Out:
# Dimension: (534, 8)
#   id      Association Population       Variant(s)   Gene(s)   PubMed  \
# 0  1  non-significant      Dutch          HLA-B40     HLA-B  1859103
# 1  2  non-significant      Dutch         HLA-DRB5  HLA-DRB5  1859103
# 2  3  non-significant    Finnish             APOB      APOB  8018664
# 3  4      significant    Finnish            APOC3     APOC3  8018664
# 4  5      significant    Finnish  rs7412,rs429358      APOE  8018664
#
#                                         Study Design  \
# 0  964 inhabitants aged 85 years and over and 244...
# 1  The apolipoprotein B Xba I polymorphism was ex...
# 2  964 inhabitants aged 85 years and over and 244...
# 3  The Sst I polymorphism was examined in 179 Fin...
# 4  The common polymorphism of apolipoprotein E (E...
#
#                                          Conclusions
# 0  Without correcting for multiple testing, HLA-D...
# 1  The frequencies of the Xba I alleles among the...
# 2  Without correcting for multiple testing, HLA-B...
# 3  The S2 allele (Sst I restriction site present)...
# 4  The frequency of the E2 allele was higher and ...

# %%
# rows that have sting in the column 'Variant(s)'
# but this string does not contains characters 'rs' with two digits after them
df_var_not_rs = df_var_not_nan[~df_var_not_nan['Variant(s)'].str.contains('.*rs\d{2}.*', flags=re.IGNORECASE)]

print("Dimension:", df_var_not_rs.shape)
df_var_not_rs.head()
# Out:
# Dimension: (229, 8)
#   id      Association Population Variant(s)   Gene(s)   PubMed  \
# 0  1  non-significant      Dutch    HLA-B40     HLA-B  1859103
# 1  2  non-significant      Dutch   HLA-DRB5  HLA-DRB5  1859103
# 2  3  non-significant    Finnish       APOB      APOB  8018664
# 3  4      significant    Finnish      APOC3     APOC3  8018664
# 6  8      significant    Finnish       APOB      APOB  8155090
#
#                                         Study Design  \
# 0  964 inhabitants aged 85 years and over and 244...
# 1  The apolipoprotein B Xba I polymorphism was ex...
# 2  964 inhabitants aged 85 years and over and 244...
# 3  The Sst I polymorphism was examined in 179 Fin...
# 6  The common polymorphism of apolipoprotein E (E...
#
#                                          Conclusions
# 0  Without correcting for multiple testing, HLA-D...
# 1  The frequencies of the Xba I alleles among the...
# 2  Without correcting for multiple testing, HLA-B...
# 3  The S2 allele (Sst I restriction site present)...
# 6  The frequency of the E4 allele was lower in th...

# %%
# rows that have sting in the column 'Variant(s)' that contains characters 'rs' with two digits after them
df_var_rs = df_var_not_nan[df_var_not_nan['Variant(s)'].str.contains('.*rs\d{2}.*', flags=re.IGNORECASE)]

print("Dimension:", df_var_rs.shape)
df_var_rs.tail()
# Out:
# Dimension: (305, 8)
#        id      Association            Population  \
# 540  G549  non-significant             Jordanian
# 541  G550  non-significant               Italian
# 543  G552  non-significant                Danish
# 546   556      significant  American (Caucasian)
# 549   559      significant                French
#
#                                             Variant(s)              Gene(s)  \
# 540                                 rs2241766,rs266729               ADIPOQ
# 541  rs6457931,rs1321312,rs4331968,rs9470367,rs6920...  PANDAR,CDKN1A,RAB44
# 543                                     rs2866164,Q95H                 MTTP
# 546                                          rs1042714                ADRB2
# 549                                    rs7412,rs429358                 APOE
#
#        PubMed                                       Study Design  \
# 540  20201642  SNPs rs266729 (-11377G/C), rs2241766 (+45T/G),...
# 541  20126416  30 SNPs were identified by sequencing the prom...
# 543  16015282  1651 participants in the Danish 1905 cohort st...
# 546  20399803  Meta-analysis of GWAS in Caucasians from four ...
# 549   8136829  Meta-analysis of GWAS in Caucasians from four ...
#
#                                            Conclusions
# 540  No significant differences were detected in th...
# 541  Rare alleles of two exon-derived SNPs, rs18012...
# 543  The risk haplotype had no significant survival...
# 546  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...

# %%
# ensure that we did not lost something during splitting of the original dataFrame
assert len(df) == len(df_var_nan) + len(df_var_rs) + len(df_var_not_rs), "Something wrong with splitting"

# %% [markdown]
# <br />
#
# ### Splitting of records with several 'rs' into several records

# %%
# Number of variants in each record in dataFrame with rs-variants.
# It is calculated by the number of commas +1
nmb_repeats = (df_var_rs['Variant(s)'].str.count(',') + 1).tolist()

assert len(df_var_rs) == len(nmb_repeats), "Problem with calculation"
print('Length of list:', len(nmb_repeats))
nmb_repeats[-5:]
# Out:
# Length of list: 305
# [2, 31, 2, 1, 2]

# %%
## alternative way:
# nmb_repeats_alt = [len(st.split(',')) for st in df_var_rs['Variant(s)']]

## make sure that two ways gives the same result
# assert len(nmb_repeats_alt) == len(nmb_repeats), "Problems with calculation"
# assert nmb_repeats_alt == nmb_repeats, "Problems with calculation (2)"
# nmb_repeats_alt[-5:]

# %%
# dublicate records in the dataFrame 'df_var_rs' that have several variants in the column 'Variant(s)'
# according to the number of these variants.
df_var_rs_extended = df_var_rs.loc[df_var_rs.index.repeat(nmb_repeats)]

print("Dimension:", df_var_rs_extended.shape)
df_var_rs_extended.tail()
# Out:
# Dimension: (3137, 8)
#        id      Association            Population       Variant(s) Gene(s)  \
# 543  G552  non-significant                Danish   rs2866164,Q95H    MTTP
# 543  G552  non-significant                Danish   rs2866164,Q95H    MTTP
# 546   556      significant  American (Caucasian)        rs1042714   ADRB2
# 549   559      significant                French  rs7412,rs429358    APOE
# 549   559      significant                French  rs7412,rs429358    APOE
#
#        PubMed                                       Study Design  \
# 543  16015282  1651 participants in the Danish 1905 cohort st...
# 543  16015282  1651 participants in the Danish 1905 cohort st...
# 546  20399803  Meta-analysis of GWAS in Caucasians from four ...
# 549   8136829  Meta-analysis of GWAS in Caucasians from four ...
# 549   8136829  Meta-analysis of GWAS in Caucasians from four ...
#
#                                            Conclusions
# 543  The risk haplotype had no significant survival...
# 543  The risk haplotype had no significant survival...
# 546  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...

# %%
# Create "list" of all variants in the column 'Variant(s)' in the dataFrame 'df_var_rs'.
# To speed up calculation, use generator.
gen_variants = (el for ls in df_var_rs['Variant(s)'] for el in ls.split(','))
gen_variants
# Out:
# <generator object <genexpr> at 0x7efec6572d60>

# %%
# change content of the columns 'Variant(s)' by splitting data
df_var_rs_extended['Variant(s)'] = list(gen_variants)

print("Dimension:", df_var_rs_extended.shape)
df_var_rs_extended.tail()
# Out:
# Dimension: (3137, 8)
#        id      Association            Population Variant(s) Gene(s)    PubMed  \
# 543  G552  non-significant                Danish  rs2866164    MTTP  16015282
# 543  G552  non-significant                Danish       Q95H    MTTP  16015282
# 546   556      significant  American (Caucasian)  rs1042714   ADRB2  20399803
# 549   559      significant                French     rs7412    APOE   8136829
# 549   559      significant                French   rs429358    APOE   8136829
#
#                                           Study Design  \
# 543  1651 participants in the Danish 1905 cohort st...
# 543  1651 participants in the Danish 1905 cohort st...
# 546  Meta-analysis of GWAS in Caucasians from four ...
# 549  Meta-analysis of GWAS in Caucasians from four ...
# 549  Meta-analysis of GWAS in Caucasians from four ...
#
#                                            Conclusions
# 543  The risk haplotype had no significant survival...
# 543  The risk haplotype had no significant survival...
# 546  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...

# %%
# in the column 'Variant(s)' of dataFrame 'df_var_rs_extended', if the first two characters are 'Rs' than change them to 'rs'
df_var_rs_extended['Variant(s)'] = df_var_rs_extended['Variant(s)'].map(lambda st: 'rs' + st[2:] if st.startswith('Rs') else st)

# %% [markdown]
# <br />
#
# ### Combining dataFrames and saving result to disk

# %%
# combine all dataFrames in one
df_result_all = pd.concat([df_var_rs_extended, df_var_not_rs, df_var_nan])

print("Dimension:", df_result_all.shape)
df_result_all.iloc[len(df_var_rs_extended)-10:len(df_var_rs_extended)+5]   # look at the middle of dataframe, where joint occured
# Out:
# Dimension: (3382, 8)
#        id      Association            Population Variant(s)  \
# 541  G550  non-significant               Italian  rs3176349
# 541  G550  non-significant               Italian   rs876581
# 541  G550  non-significant               Italian  rs6457938
# 541  G550  non-significant               Italian  rs6457940
# 541  G550  non-significant               Italian  rs2145047
# 543  G552  non-significant                Danish  rs2866164
# 543  G552  non-significant                Danish       Q95H
# 546   556      significant  American (Caucasian)  rs1042714
# 549   559      significant                French     rs7412
# 549   559      significant                French   rs429358
# 0       1  non-significant                 Dutch    HLA-B40
# 1       2  non-significant                 Dutch   HLA-DRB5
# 2       3  non-significant               Finnish       APOB
# 3       4      significant               Finnish      APOC3
# 6       8      significant               Finnish       APOB
#
#                  Gene(s)    PubMed  \
# 541  PANDAR,CDKN1A,RAB44  20126416
# 541  PANDAR,CDKN1A,RAB44  20126416
# 541  PANDAR,CDKN1A,RAB44  20126416
# 541  PANDAR,CDKN1A,RAB44  20126416
# 541  PANDAR,CDKN1A,RAB44  20126416
# 543                 MTTP  16015282
# 543                 MTTP  16015282
# 546                ADRB2  20399803
# 549                 APOE   8136829
# 549                 APOE   8136829
# 0                  HLA-B   1859103
# 1               HLA-DRB5   1859103
# 2                   APOB   8018664
# 3                  APOC3   8018664
# 6                   APOB   8155090
#
#                                           Study Design  \
# 541  30 SNPs were identified by sequencing the prom...
# 541  30 SNPs were identified by sequencing the prom...
# 541  30 SNPs were identified by sequencing the prom...
# 541  30 SNPs were identified by sequencing the prom...
# 541  30 SNPs were identified by sequencing the prom...
# 543  1651 participants in the Danish 1905 cohort st...
# 543  1651 participants in the Danish 1905 cohort st...
# 546  Meta-analysis of GWAS in Caucasians from four ...
# 549  Meta-analysis of GWAS in Caucasians from four ...
# 549  Meta-analysis of GWAS in Caucasians from four ...
# 0    964 inhabitants aged 85 years and over and 244...
# 1    The apolipoprotein B Xba I polymorphism was ex...
# 2    964 inhabitants aged 85 years and over and 244...
# 3    The Sst I polymorphism was examined in 179 Fin...
# 6    The common polymorphism of apolipoprotein E (E...
#
#                                            Conclusions
# 541  Rare alleles of two exon-derived SNPs, rs18012...
# 541  Rare alleles of two exon-derived SNPs, rs18012...
# 541  Rare alleles of two exon-derived SNPs, rs18012...
# 541  Rare alleles of two exon-derived SNPs, rs18012...
# 541  Rare alleles of two exon-derived SNPs, rs18012...
# 543  The risk haplotype had no significant survival...
# 543  The risk haplotype had no significant survival...
# 546  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...
# 0    Without correcting for multiple testing, HLA-D...
# 1    The frequencies of the Xba I alleles among the...
# 2    Without correcting for multiple testing, HLA-B...
# 3    The S2 allele (Sst I restriction site present)...
# 6    The frequency of the E4 allele was lower in th...

# %%
# save all results together
df_result_all.to_csv(output / 'longevity_genes_splitted_all.csv', index=False)

# %% [markdown]
# <br />

# %%
# save only records that contain 'rs' at the beginning
df_result_rs = df_var_rs_extended[df_var_rs_extended['Variant(s)'].str.startswith('rs')]

print("Dimension:", df_result_rs.shape)
df_result_rs.tail()
# Out:
# Dimension: (3129, 8)
#        id      Association            Population Variant(s)  \
# 541  G550  non-significant               Italian  rs2145047
# 543  G552  non-significant                Danish  rs2866164
# 546   556      significant  American (Caucasian)  rs1042714
# 549   559      significant                French     rs7412
# 549   559      significant                French   rs429358
#
#                  Gene(s)    PubMed  \
# 541  PANDAR,CDKN1A,RAB44  20126416
# 543                 MTTP  16015282
# 546                ADRB2  20399803
# 549                 APOE   8136829
# 549                 APOE   8136829
#
#                                           Study Design  \
# 541  30 SNPs were identified by sequencing the prom...
# 543  1651 participants in the Danish 1905 cohort st...
# 546  Meta-analysis of GWAS in Caucasians from four ...
# 549  Meta-analysis of GWAS in Caucasians from four ...
# 549  Meta-analysis of GWAS in Caucasians from four ...
#
#                                            Conclusions
# 541  Rare alleles of two exon-derived SNPs, rs18012...
# 543  The risk haplotype had no significant survival...
# 546  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...
# 549  There were 273 single-nucleotide polymorphism ...

# %%
df_result_rs.to_csv(output / 'longevity_genes_splitted_rs.csv', index=False)

# %% [markdown]
# <br />

# %%
# save other records, that do not contain 'rs' at the beginning
df_result_not_rs = pd.concat([df_var_rs_extended[~df_var_rs_extended['Variant(s)'].str.startswith('rs')],
                              df_var_not_rs,
                              df_var_nan
                             ])

print("Dimension:", df_result_not_rs.shape)
df_result_not_rs
# Out:
# Dimension: (253, 8)
#        id      Association                                         Population  \
# 403  G410  non-significant                                          Bulgarian
# 403  G410  non-significant                                          Bulgarian
# 407  G414  non-significant                                             German
# 415  G423  non-significant                                   Ashkenazi Jewish
# 415  G423  non-significant                                   Ashkenazi Jewish
# ..    ...              ...                                                ...
# 369   375      significant                                            Finnish
# 373   379      significant                                            Italian
# 381   387      significant  European (Danish, Finnish, South Italian and G...
# 547   557  non-significant                               American (Caucasian)
# 548   558  non-significant                               American (Caucasian)
#
#     Variant(s) Gene(s)    PubMed  \
# 403    -819C/T    IL10  15050300
# 403    -592C/A    IL10  15050300
# 407     Q/H 95    MTTP  15911777
# 415  APM1+2019  ADIPOQ  18511746
# 415   APM+2019  ADIPOQ  18511746
# ..         ...     ...       ...
# 369        NaN    TP53  12483296
# 373        NaN    TP53  10463944
# 381        NaN    TP53  24341918
# 547        NaN    TP53  20824210
# 548        NaN    TP53  20824210
#
#                                           Study Design  \
# 403  -1082G/A, -819 C/T and -592 C/A SNPs were exam...
# 403  -1082G/A, -819 C/T and -592 C/A SNPs were exam...
# 407  rs1800591, rs2866164, and Q/H 95 SNPs were exa...
# 415  Adiponectin levels and variants in the adipone...
# 415  Adiponectin levels and variants in the adipone...
# ..                                                 ...
# 369  Inherited mtDNA markers were analyzed between ...
# 373  Associations between variation in SNPs in the ...
# 381  Allele and genotype distributions of rs1333049...
# 547  After 16 SNPs over LMNA gene were genotyped in...
# 548  After 16 SNPs over LMNA gene were genotyped in...
#
#                                            Conclusions
# 403  Genotype -1082G/A, -819 C/C, -592 C/C was posi...
# 403  Genotype -1082G/A, -819 C/C, -592 C/C was posi...
# 407  No evidence for association was detected betwe...
# 415  Frequencies were not significantly different b...
# 415  Frequencies were not significantly different b...
# ..                                                 ...
# 369  Male centenarians emerged in northern Italy as...
# 373  Carriers of the minor allele of rs12778366 had...
# 381  The frequency of the GG genotype in centenaria...
# 547  A meta-analysis combining results from 5 sets ...
# 548  A meta-analysis combining results from 5 sets ...
#
# [253 rows x 8 columns]

# %%
df_result_not_rs.to_csv(output /'longevity_genes_splitted_not_rs.csv', index=False)

# %% [markdown]
# <br />

# %%
# ensure that we did lost something
assert len(df_var_rs_extended) + len(df_var_not_rs) + len(df_var_nan) == len(df_result_all), "Something was lost"
assert len(df_result_all) == len(df_result_rs) + len(df_result_not_rs), "Something was lost (2)"
print('Done')
# Out:
# Done
